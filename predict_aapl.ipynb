# %%
import yfinance as yf

# %%
aapl = yf.Ticker("NVDA")
aapl.info["forwardPE"]
# Out:
# 41.4466

# %%
aapl = aapl.history(period="max")

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0
# ...                              ...        ...           ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0
#
# [11276 rows x 7 columns]

# %%
aapl.index
# Out:
# DatetimeIndex(['1980-12-12 00:00:00-05:00', '1980-12-15 00:00:00-05:00',
#                '1980-12-16 00:00:00-05:00', '1980-12-17 00:00:00-05:00',
#                '1980-12-18 00:00:00-05:00', '1980-12-19 00:00:00-05:00',
#                '1980-12-22 00:00:00-05:00', '1980-12-23 00:00:00-05:00',
#                '1980-12-24 00:00:00-05:00', '1980-12-26 00:00:00-05:00',
#                ...
#                '2025-08-26 00:00:00-04:00', '2025-08-27 00:00:00-04:00',
#                '2025-08-28 00:00:00-04:00', '2025-08-29 00:00:00-04:00',
#                '2025-09-02 00:00:00-04:00', '2025-09-03 00:00:00-04:00',
#                '2025-09-04 00:00:00-04:00', '2025-09-05 00:00:00-04:00',
#                '2025-09-08 00:00:00-04:00', '2025-09-09 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=11276, freq=None)

# %%
aapl.plot.line(y="Close",use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
aapl["Tomorrow"] = aapl["Close"].shift(-1)

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits    Tomorrow
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0    0.093347
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0    0.086495
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0    0.088636
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0    0.091206
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0    0.096772
# ...                              ...        ...           ...         ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0  239.779999
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0  239.690002
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0  237.880005
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0  234.350006
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0         NaN
#
# [11276 rows x 8 columns]

# %%
aapl["Target"] = (aapl["Tomorrow"]>aapl["Close"]).astype(int)

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits    Tomorrow  \
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0    0.093347
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0    0.086495
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0    0.088636
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0    0.091206
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0    0.096772
# ...                              ...        ...           ...         ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0  239.779999
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0  239.690002
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0  237.880005
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0  234.350006
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0         NaN
#
#                            Target
# Date
# 1980-12-12 00:00:00-05:00       0
# 1980-12-15 00:00:00-05:00       0
# 1980-12-16 00:00:00-05:00       1
# 1980-12-17 00:00:00-05:00       1
# 1980-12-18 00:00:00-05:00       1
# ...                           ...
# 2025-09-03 00:00:00-04:00       1
# 2025-09-04 00:00:00-04:00       0
# 2025-09-05 00:00:00-04:00       0
# 2025-09-08 00:00:00-04:00       0
# 2025-09-09 00:00:00-04:00       0
#
# [11276 rows x 9 columns]

# %%
aapl = aapl.loc["2000-01-01":].copy()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = aapl.iloc[:-100]
test= aapl.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

predictions = model.predict(test[predictors])

# %%
import pandas as pd 

predictions = pd.Series(predictions, index=test.index)

# %%
precision_score(test["Target"], predictions)
# Out:
# 0.6

# %%
def predict(train, test, predictors, model): 
        model.fit(train[predictors], train["Target"])
        predictions = model.predict(test[predictors])
        predictions = pd.Series(predictions, index=test.index, name = "Predictions")
        combined = pd.concat([test["Target"], predictions], axis=1)
        return combined

# %%
def backtest(data, model, predictors, start=1000, step=250):
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(aapl, model, predictors)

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5261228230980751

# %%
horizons = [2, 5, 60, 250, 1000]

new_predictors = []

for horizon in horizons:
    rolling_averages = aapl.rolling(horizon).mean()
    
    ratio_column = f"Close Ratio_{horizon}"
    aapl[ratio_column] = aapl["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    aapl[trend_column] = aapl.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
aapl = aapl.dropna()

# %%
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
import numpy as np

# %%
n_splits = 5
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
X = aapl.drop(columns=["Target"])  # Features
y = aapl["Target"]  # Target

# %%
# %% Predict function using XGBoost
def predict(train, test, predictors, model):
    # Train the model on the current fold
    model.fit(train[predictors], train["Target"])
    
    # Predict probabilities for the positive class (class 1)
    predictions_proba = model.predict_proba(test[predictors])[:,1]
    
    # Apply a threshold of 0.6 to classify as 1 or 0
    predictions = np.where(predictions_proba >= 0.6, 1, 0)
    
    # Create a pandas Series of predictions, indexed by the test data
    predictions = pd.Series(predictions, index=test.index, name="Predictions")
    
    # Combine predictions with actual target values
    combined = pd.concat([test["Target"], predictions], axis=1)
    return combined

# %% Backtest function
def backtest(data, model, predictors, start=1000, step=250):
    print("\nbacktesting")
    all_predictions = []
    for i in range(start, data.shape[0], step):
        # Create train and test datasets for backtesting
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()

        # Make predictions for the current test set
        predictions = predict(train, test, predictors, model)
        
        # Append predictions to the list of all predictions
        all_predictions.append(predictions)

    # Concatenate all predictions and return the final dataframe
    return pd.concat(all_predictions)

# %%
n_splits = 5
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
models = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"\n<== Training fold {fold + 1}/{n_splits} ==>")
        
    # Split into train and validation sets for the fold
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # Initialize the XGBoost model
    model = xgb.XGBClassifier(
        n_estimators=5000,
        learning_rate=0.03,
        max_depth=10,
        min_child_weight=8,
        subsample=0.85,
        colsample_bytree=0.5,
        reg_alpha=0.8,
        reg_lambda=0.4,
        random_state=2005,
        tree_method="hist",  # fast and good for tabular
    )
    
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Run backtest on the full dataset (not just on the fold)
    predictions = backtest(aapl, model, new_predictors)
    
    # Calculate precision score on the predictions from backtest
    precision = precision_score(predictions["Target"], predictions["Predictions"])
    print(f"Precision Score for Fold {fold + 1}: {precision}")
    
    # Store the trained model
    models.append(model)

print("\nXGBoost model training complete.")
# Out:
# <== Training fold 1/5 ==>
#
# backtesting
# Precision Score for Fold 1: 0.531479538300105
#
# <== Training fold 2/5 ==>
#
# backtesting
# Precision Score for Fold 2: 0.531479538300105
#
# <== Training fold 3/5 ==>
#
# backtesting
# Precision Score for Fold 3: 0.531479538300105
#
# <== Training fold 4/5 ==>
#
# backtesting
# Precision Score for Fold 4: 0.531479538300105
#
# <== Training fold 5/5 ==>
#
# backtesting
# Precision Score for Fold 5: 0.531479538300105
#
# XGBoost model training complete.

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.531479538300105
