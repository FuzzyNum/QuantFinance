# %%
import yfinance as yf

# %%
aapl = yf.Ticker("AAPL")
aapl.info["forwardPE"]
# Out:
# 28.200962

# %%
aapl = aapl.history(period="max")

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0
# ...                              ...        ...           ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0
#
# [11276 rows x 7 columns]

# %%
aapl.index
# Out:
# DatetimeIndex(['1980-12-12 00:00:00-05:00', '1980-12-15 00:00:00-05:00',
#                '1980-12-16 00:00:00-05:00', '1980-12-17 00:00:00-05:00',
#                '1980-12-18 00:00:00-05:00', '1980-12-19 00:00:00-05:00',
#                '1980-12-22 00:00:00-05:00', '1980-12-23 00:00:00-05:00',
#                '1980-12-24 00:00:00-05:00', '1980-12-26 00:00:00-05:00',
#                ...
#                '2025-08-26 00:00:00-04:00', '2025-08-27 00:00:00-04:00',
#                '2025-08-28 00:00:00-04:00', '2025-08-29 00:00:00-04:00',
#                '2025-09-02 00:00:00-04:00', '2025-09-03 00:00:00-04:00',
#                '2025-09-04 00:00:00-04:00', '2025-09-05 00:00:00-04:00',
#                '2025-09-08 00:00:00-04:00', '2025-09-09 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=11276, freq=None)

# %%
aapl.plot.line(y="Close",use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
aapl["Tomorrow"] = aapl["Close"].shift(-1)

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits    Tomorrow
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0    0.093347
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0    0.086495
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0    0.088636
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0    0.091206
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0    0.096772
# ...                              ...        ...           ...         ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0  239.779999
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0  239.690002
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0  237.880005
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0  234.350006
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0         NaN
#
# [11276 rows x 8 columns]

# %%
aapl["Target"] = (aapl["Tomorrow"]>aapl["Close"]).astype(int)

# %%
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.780502  233.369995  234.350006
#
#                               Volume  Dividends  Stock Splits    Tomorrow  \
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0    0.093347
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0    0.086495
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0    0.088636
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0    0.091206
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0    0.096772
# ...                              ...        ...           ...         ...
# 2025-09-03 00:00:00-04:00   66427800        0.0           0.0  239.779999
# 2025-09-04 00:00:00-04:00   47549400        0.0           0.0  239.690002
# 2025-09-05 00:00:00-04:00   54870400        0.0           0.0  237.880005
# 2025-09-08 00:00:00-04:00   48999500        0.0           0.0  234.350006
# 2025-09-09 00:00:00-04:00   65167049        0.0           0.0         NaN
#
#                            Target
# Date
# 1980-12-12 00:00:00-05:00       0
# 1980-12-15 00:00:00-05:00       0
# 1980-12-16 00:00:00-05:00       1
# 1980-12-17 00:00:00-05:00       1
# 1980-12-18 00:00:00-05:00       1
# ...                           ...
# 2025-09-03 00:00:00-04:00       1
# 2025-09-04 00:00:00-04:00       0
# 2025-09-05 00:00:00-04:00       0
# 2025-09-08 00:00:00-04:00       0
# 2025-09-09 00:00:00-04:00       0
#
# [11276 rows x 9 columns]

# %%
aapl = aapl.loc["2000-01-01":].copy()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = aapl.iloc[:-100]
test= aapl.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

predictions = model.predict(test[predictors])

# %%
import pandas as pd 

predictions = pd.Series(predictions, index=test.index)

# %%
precision_score(test["Target"], predictions)
# Out:
# 0.5283018867924528

# %%
def predict(train, test, predictors, model): 
        model.fit(train[predictors], train["Target"])
        predictions = model.predict(test[predictors])
        predictions = pd.Series(predictions, index=test.index, name = "Predictions")
        combined = pd.concat([test["Target"], predictions], axis=1)
        return combined

# %%
def backtest(data, model,predictors,start=1000,step=250):
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(aapl, model, predictors)

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.52737881508079

# %%
horizons = [2, 5, 60, 250, 1000]

new_predictors = []

for horizon in horizons:
    rolling_averages = aapl.rolling(horizon).mean()
    
    ratio_column = f"Close Ratio_{horizon}"
    aapl[ratio_column] = aapl["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    aapl[trend_column] = aapl.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
aapl = aapl.dropna()

# %%
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
import numpy as np

# %%
n_splits = 5
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
X = aapl.drop(columns=["Target"])  # Features
y = aapl["Target"]  # Target

# %%
n_splits = 5
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
models = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"\n<== Training fold {fold + 1}/{n_splits} ==>")
        
    # Split into train and validation sets for the fold
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # Initialize the XGBoost model
    model = xgb.XGBClassifier(
        n_estimators=5000,
        learning_rate=0.03,
        max_depth=10,
        min_child_weight=8,
        subsample=0.85,
        colsample_bytree=0.5,
        reg_alpha=0.8,
        reg_lambda=0.4,
        random_state=2005,
        eval_metric="auc",
        tree_method="hist",  # fast and good for tabular
        use_label_encoder=False
    )
    
    # Fit the model on the training data
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=100)
    
    # Run backtest on the full dataset (not just on the fold)
    predictions = backtest(aapl, model, new_predictors)
    
    # Calculate precision score on the predictions from backtest
    precision = precision_score(predictions["Target"], predictions["Predictions"])
    print(f"Precision Score for Fold {fold + 1}: {precision}")
    
    # Store the trained model
    models.append(model)

print("\nXGBoost model training complete.")
# Out:
# <== Training fold 1/5 ==>
# [0]	validation_0-auc:0.50508
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:48:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [100]	validation_0-auc:0.56763
# [200]	validation_0-auc:0.58713
# [300]	validation_0-auc:0.59494
# [400]	validation_0-auc:0.60669
# [500]	validation_0-auc:0.61185
# [600]	validation_0-auc:0.61717
# [700]	validation_0-auc:0.62359
# [800]	validation_0-auc:0.62773
# [900]	validation_0-auc:0.62994
# [1000]	validation_0-auc:0.63060
# [1100]	validation_0-auc:0.63456
# [1200]	validation_0-auc:0.63681
# [1300]	validation_0-auc:0.63982
# [1400]	validation_0-auc:0.64013
# [1500]	validation_0-auc:0.64218
# [1600]	validation_0-auc:0.64193
# [1700]	validation_0-auc:0.64155
# [1800]	validation_0-auc:0.64097
# [1900]	validation_0-auc:0.64241
# [2000]	validation_0-auc:0.64263
# [2100]	validation_0-auc:0.64305
# [2200]	validation_0-auc:0.64388
# [2300]	validation_0-auc:0.64385
# [2400]	validation_0-auc:0.64522
# [2500]	validation_0-auc:0.64528
# [2600]	validation_0-auc:0.64615
# [2700]	validation_0-auc:0.64587
# [2800]	validation_0-auc:0.64630
# [2900]	validation_0-auc:0.64608
# [3000]	validation_0-auc:0.64694
# [3100]	validation_0-auc:0.64698
# [3200]	validation_0-auc:0.64739
# [3300]	validation_0-auc:0.64780
# [3400]	validation_0-auc:0.64823
# [3500]	validation_0-auc:0.64893
# [3600]	validation_0-auc:0.64942
# [3700]	validation_0-auc:0.64969
# [3800]	validation_0-auc:0.65001
# [3900]	validation_0-auc:0.64985
# [4000]	validation_0-auc:0.64982
# [4100]	validation_0-auc:0.65020
# [4200]	validation_0-auc:0.64974
# [4300]	validation_0-auc:0.65013
# [4400]	validation_0-auc:0.65000
# [4500]	validation_0-auc:0.65016
# [4600]	validation_0-auc:0.65030
# [4700]	validation_0-auc:0.65033
# [4800]	validation_0-auc:0.65090
# [4900]	validation_0-auc:0.65113
# [4999]	validation_0-auc:0.65113
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:48:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:48:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:48:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:48:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:49:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:49:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:49:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:49:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:50:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:50:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:50:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:50:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:51:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:51:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:51:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:51:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:52:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 32
#      29 model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=100)
#      31 # Run backtest on the full dataset (not just on the fold)
# ---> 32 predictions = backtest(aapl, model, new_predictors)
#      34 # Calculate precision score on the predictions from backtest
#      35 precision = precision_score(predictions["Target"], predictions["Predictions"])
#
# Cell In[17], line 6, in backtest(data, model, predictors, start, step)
#       4     train = data.iloc[0:i].copy()
#       5     test = data.iloc[i:(i+step)].copy()
# ----> 6     predictions = predict(train, test, predictors, model)
#       7     all_predictions.append(predictions)
#       8 return pd.concat(all_predictions)
#
# Cell In[26], line 2, in predict(train, test, predictors, model)
#       1 def predict(train, test, predictors, model):
# ----> 2         model.fit(train[predictors], train["Target"])
#       3         predictions = model.predict_proba(test[predictors])[:,1]
#       4         predictions[predictions >= .6] = 1
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/sklearn.py:1683, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1661 model, metric, params, feature_weights = self._configure_fit(
#    1662     xgb_model, params, feature_weights
#    1663 )
#    1664 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1665     missing=self.missing,
#    1666     X=X,
#    (...)   1680     feature_types=self.feature_types,
#    1681 )
# -> 1683 self._Booster = train(
#    1684     params,
#    1685     train_dmatrix,
#    1686     self.get_num_boosting_rounds(),
#    1687     evals=evals,
#    1688     early_stopping_rounds=self.early_stopping_rounds,
#    1689     evals_result=evals_result,
#    1690     obj=obj,
#    1691     custom_metric=metric,
#    1692     verbose_eval=verbose,
#    1693     xgb_model=model,
#    1694     callbacks=self.callbacks,
#    1695 )
#    1697 if not callable(self.objective):
#    1698     self.objective = params["objective"]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
def predict(train, test, predictors, model): 
        model.fit(train[predictors], train["Target"])
        predictions = model.predict_proba(test[predictors])[:,1]
        predictions[predictions >= .6] = 1
        predictions[predictions < .6] = 0
        predictions = pd.Series(predictions, index=test.index, name = "Predictions")
        combined = pd.concat([test["Target"], predictions], axis=1)
        return combined

# %%
predictions = backtest(aapl, model, new_predictors)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [18:52:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 predictions = backtest(aapl, model, new_predictors)
#
# Cell In[17], line 6, in backtest(data, model, predictors, start, step)
#       4     train = data.iloc[0:i].copy()
#       5     test = data.iloc[i:(i+step)].copy()
# ----> 6     predictions = predict(train, test, predictors, model)
#       7     all_predictions.append(predictions)
#       8 return pd.concat(all_predictions)
#
# Cell In[26], line 2, in predict(train, test, predictors, model)
#       1 def predict(train, test, predictors, model):
# ----> 2         model.fit(train[predictors], train["Target"])
#       3         predictions = model.predict_proba(test[predictors])[:,1]
#       4         predictions[predictions >= .6] = 1
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/sklearn.py:1683, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1661 model, metric, params, feature_weights = self._configure_fit(
#    1662     xgb_model, params, feature_weights
#    1663 )
#    1664 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1665     missing=self.missing,
#    1666     X=X,
#    (...)   1680     feature_types=self.feature_types,
#    1681 )
# -> 1683 self._Booster = train(
#    1684     params,
#    1685     train_dmatrix,
#    1686     self.get_num_boosting_rounds(),
#    1687     evals=evals,
#    1688     early_stopping_rounds=self.early_stopping_rounds,
#    1689     evals_result=evals_result,
#    1690     obj=obj,
#    1691     custom_metric=metric,
#    1692     verbose_eval=verbose,
#    1693     xgb_model=model,
#    1694     callbacks=self.callbacks,
#    1695 )
#    1697 if not callable(self.objective):
#    1698     self.objective = params["objective"]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.52737881508079
